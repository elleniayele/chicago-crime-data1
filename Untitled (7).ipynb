# %%
import os,glob

## Getting the home folder from environment variables
home_folder = os.environ['HOME']
# print("- Your Home Folder is: " + home_folder)

## Check for downloads folder
if 'Downloads' in os.listdir(home_folder):
    
    
    # Print the Downloads folder path
    dl_folder = os.path.abspath(os.path.join(home_folder,'Downloads'))
    print(f"- Your Downloads folder is '{dl_folder}/'\n")
    
    ## checking for crime files using glob
    crime_files = sorted(glob.glob(dl_folder+'/**/Crimes_-_2001_to_Present*',recursive=True))
    
    # If more than 
    if len(crime_files)==1:
        RAW_FILE = crime_files[0]
        
    elif len(crime_files)>1:
        print('[i] The following files were found:')
        
        for i, fname in enumerate(crime_files):
            print(f"\tcrime_files[{i}] = '{fname}'")
        print(f'\n- Please fill in the RAW_FILE variable in the code cell below with the correct filepath.')

else:
    print(f'[!] Could not programmatically find your downloads folder.')
    print('- Try using Finder (on Mac) or File Explorer (Windows) to navigate to your Downloads folder.')
# Out:
# - Your Downloads folder is 'C:\Users\awot1\Downloads/'

# %%
## DO NOT CHANGE THIS CELL
if RAW_FILE == r"YOUR FILEPATH HERE":
	raise Exception("You must update the RAW_FILE variable in the previous cell to match your local filepath.")
	
RAW_FILE
# Out:
# 'C:\\Users\\awot1\\Downloads\\Crimes_-_2001_to_Present.csv'

# %%
## (Optional) SET THE FOLDER FOR FINAL FILES
OUTPUT_FOLDER = 'Data/Chicago/'
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# %%
import pandas as pd
chicago_full = pd.read_csv(RAW_FILE)
chicago_full
# Out:
#                ID Case Number                    Date                   Block  \
# 0        11646166    JC213529  09/01/2018 12:01:00 AM   082XX S INGLESIDE AVE
# 1        11645836    JC212333  05/01/2016 12:25:00 AM     055XX S ROCKWELL ST
# 2        11449702    JB373031  07/31/2018 01:30:00 PM  009XX E HYDE PARK BLVD
# 3        11643334    JC209972  12/19/2018 04:30:00 PM  056XX W WELLINGTON AVE
# 4        11645527    JC212744  02/02/2015 10:00:00 AM      069XX W ARCHER AVE
# ...           ...         ...                     ...                     ...
# 7883246  13128007    JG325985  06/21/2023 08:00:00 PM  031XX N CALIFORNIA AVE
# 7883247  13128324    JG326502  05/13/2023 12:00:00 PM       020XX W CERMAK RD
# 7883248  13128375    JG326564  06/24/2023 01:29:00 PM    069XX N HAMILTON AVE
# 7883249  13129172    JG327619  06/20/2023 04:00:00 AM   028XX N MAPLEWOOD AVE
# 7883250  13129823    JG328250  06/28/2023 06:00:00 PM      059XX S KEELER AVE
#
#          IUCR        Primary Type                          Description  \
# 0        0810               THEFT                            OVER $500
# 1        1153  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 2        2024           NARCOTICS                  POSS: HEROIN(WHITE)
# 3        1320     CRIMINAL DAMAGE                           TO VEHICLE
# 4        1153  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# ...       ...                 ...                                  ...
# 7883246  1320     CRIMINAL DAMAGE                           TO VEHICLE
# 7883247  1120  DECEPTIVE PRACTICE                              FORGERY
# 7883248  1330   CRIMINAL TRESPASS                              TO LAND
# 7883249  0460             BATTERY                               SIMPLE
# 7883250  0810               THEFT                            OVER $500
#
#         Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 0                  RESIDENCE   False      True  ...   8.0            44.0
# 1                        NaN   False     False  ...  15.0            63.0
# 2                     STREET    True     False  ...   5.0            41.0
# 3                     STREET   False     False  ...  31.0            19.0
# 4                      OTHER   False     False  ...  23.0            56.0
# ...                      ...     ...       ...  ...   ...             ...
# 7883246               STREET   False     False  ...  35.0            21.0
# 7883247    CURRENCY EXCHANGE   False     False  ...  25.0            31.0
# 7883248            RESIDENCE   False     False  ...  40.0             2.0
# 7883249            RESIDENCE   False      True  ...  35.0            21.0
# 7883250               STREET   False     False  ...  13.0            65.0
#
#          FBI Code  X Coordinate Y Coordinate  Year              Updated On  \
# 0              06           NaN          NaN  2018  04/06/2019 04:04:43 PM
# 1              11           NaN          NaN  2016  04/06/2019 04:04:43 PM
# 2              18           NaN          NaN  2018  04/09/2019 04:24:58 PM
# 3              14           NaN          NaN  2018  04/04/2019 04:16:11 PM
# 4              11           NaN          NaN  2015  04/06/2019 04:04:43 PM
# ...           ...           ...          ...   ...                     ...
# 7883246        14     1157169.0    1920611.0  2023  08/19/2023 03:40:26 PM
# 7883247        10     1163211.0    1889404.0  2023  08/19/2023 03:40:26 PM
# 7883248        26     1160740.0    1946176.0  2023  08/19/2023 03:40:26 PM
# 7883249       08B     1158868.0    1918755.0  2023  08/19/2023 03:40:26 PM
# 7883250        06     1149387.0    1864869.0  2023  08/19/2023 03:40:26 PM
#
#           Latitude  Longitude                       Location
# 0              NaN        NaN                            NaN
# 1              NaN        NaN                            NaN
# 2              NaN        NaN                            NaN
# 3              NaN        NaN                            NaN
# 4              NaN        NaN                            NaN
# ...            ...        ...                            ...
# 7883246  41.937926 -87.697782  (41.937925817, -87.697782474)
# 7883247  41.852166 -87.676455   (41.85216632, -87.676455032)
# 7883248  42.008004 -87.683946  (42.008003927, -87.683946124)
# 7883249  41.932798 -87.691589  (41.932798095, -87.691589364)
# 7883250  41.785118 -87.727828  (41.785117789, -87.727827896)
#
# [7883251 rows x 22 columns]

# %%
# this cell can take up to 1 min to run
date_format = "%m/%d/%Y %H:%M:%S %p"

chicago_full['Datetime'] = pd.to_datetime(chicago_full['Date'], format=date_format)
chicago_full = chicago_full.sort_values('Datetime')
chicago_full
# Out:
#                ID Case Number                    Date                  Block  \
# 4250332   3769790    HL141452  01/01/2001 01:00:00 PM       121XX S LOWE AVE
# 2453889   1311123     G001792  01/01/2001 01:00:00 AM          022XX W 21 ST
# 105070    1325760     G001074  01/01/2001 01:00:00 PM  029XX S CALIFORNIA AV
# 5958434   6808288    HR218860  01/01/2001 01:00:00 PM   004XX E OAKWOOD BLVD
# 1159475   1319931     G001079  01/01/2001 01:00:00 PM    060XX S ARTESIAN AV
# ...           ...         ...                     ...                    ...
# 114960   13193650    JG403958  08/30/2023 12:00:00 AM        057XX W OHIO ST
# 115297   13193026    JG403252  08/30/2023 12:00:00 AM        011XX S TROY ST
# 115011   13193535    JG403719  08/30/2023 12:00:00 AM    044XX W HARRISON ST
# 114840   13193784    JG404311  08/30/2023 12:00:00 AM  048XX S LAKE PARK AVE
# 115201   13193480    JG403819  08/30/2023 12:00:00 AM  106XX S GREEN BAY AVE
#
#          IUCR         Primary Type  \
# 4250332  0842                THEFT
# 2453889  1320      CRIMINAL DAMAGE
# 105070   1811            NARCOTICS
# 5958434  0840                THEFT
# 1159475  0460              BATTERY
# ...       ...                  ...
# 114960   0810                THEFT
# 115297   051A              ASSAULT
# 115011   0479              BATTERY
# 114840   0910  MOTOR VEHICLE THEFT
# 115201   0910  MOTOR VEHICLE THEFT
#
#                                              Description  \
# 4250332                          AGG: FINANCIAL ID THEFT
# 2453889                                       TO VEHICLE
# 105070                      POSS: CANNABIS 30GMS OR LESS
# 5958434                    FINANCIAL ID THEFT: OVER $300
# 1159475                                           SIMPLE
# ...                                                  ...
# 114960                                         OVER $500
# 115297                              AGGRAVATED - HANDGUN
# 115011   AGGRAVATED - HANDS, FISTS, FEET, SERIOUS INJURY
# 114840                                        AUTOMOBILE
# 115201                                        AUTOMOBILE
#
#                            Location Description  Arrest  Domestic  ...  \
# 4250332                               RESIDENCE   False     False  ...
# 2453889                                  STREET   False     False  ...
# 105070             GOVERNMENT BUILDING/PROPERTY    True     False  ...
# 5958434                               APARTMENT   False     False  ...
# 1159475                               RESIDENCE   False      True  ...
# ...                                         ...     ...       ...  ...
# 114960                                   STREET   False     False  ...
# 115297                                APARTMENT   False      True  ...
# 115011                                APARTMENT    True      True  ...
# 114840                                   STREET   False     False  ...
# 115201   PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False  ...
#
#          Community Area  FBI Code  X Coordinate  Y Coordinate  Year  \
#
2023 12:00:00 AM  MOTOR VEHICLE THEFT
# 2023-08-30 12:00:00  13193480  08/30/2023 12:00:00 AM  MOTOR VEHICLE THEFT
#
#                                                          Description  \
# Datetime
# 2001-01-01 01:00:00                          AGG: FINANCIAL ID THEFT
# 2001-01-01 01:00:00                                       TO VEHICLE
# 2001-01-01 01:00:00                     POSS: CANNABIS 30GMS OR LESS
# 2001-01-01 01:00:00                    FINANCIAL ID THEFT: OVER $300
# 2001-01-01 01:00:00                                           SIMPLE
# ...                                                              ...
# 2023-08-30 12:00:00                                        OVER $500
# 2023-08-30 12:00:00                             AGGRAVATED - HANDGUN
# 2023-08-30 12:00:00  AGGRAVATED - HANDS, FISTS, FEET, SERIOUS INJURY
# 2023-08-30 12:00:00                                       AUTOMOBILE
# 2023-08-30 12:00:00                                       AUTOMOBILE
#
#                                        Location Description  Arrest  Domestic  \
# Datetime
# 2001-01-01 01:00:00                               RESIDENCE   False     False
# 2001-01-01 01:00:00                                  STREET   False     False
# 2001-01-01 01:00:00            GOVERNMENT BUILDING/PROPERTY    True     False
# 2001-01-01 01:00:00                               APARTMENT   False     False
# 2001-01-01 01:00:00                               RESIDENCE   False      True
# ...                                                     ...     ...       ...
# 2023-08-30 12:00:00                                  STREET   False     False
# 2023-08-30 12:00:00                               APARTMENT   False      True
# 2023-08-30 12:00:00                               APARTMENT    True      True
# 2023-08-30 12:00:00                                  STREET   False     False
# 2023-08-30 12:00:00  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False
#
#                      Beat  District  Ward  Year   Latitude  Longitude
# Datetime
# 2001-01-01 01:00:00   523       5.0  34.0  2001  41.673171 -87.638000
# 2001-01-01 01:00:00  1223      12.0   NaN  2001  41.854014 -87.681909
# 2001-01-01 01:00:00  1033      10.0   NaN  2001        NaN        NaN
# 2001-01-01 01:00:00   213       2.0   3.0  2001  41.822551 -87.615632
# 2001-01-01 01:00:00   825       8.0   NaN  2001  41.783892 -87.684841
# ...                   ...       ...   ...   ...        ...        ...
# 2023-08-30 12:00:00  1512      15.0  29.0  2023  41.891064 -87.768444
# 2023-08-30 12:00:00  1134      11.0  24.0  2023  41.867636 -87.704486
# 2023-08-30 12:00:00  1131      11.0  28.0  2023  41.873638 -87.735923
# 2023-08-30 12:00:00   222       2.0   4.0  2023  41.807499 -87.590234
# 2023-08-30 12:00:00   432       4.0  10.0  2023  41.701789 -87.541347
#
# [7883251 rows x 13 columns]

# %%
# unique # of year bins
year_bins = chicago_final['Year'].astype(str).unique()
year_bins
# Out:
# array(['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype=object)

# %%
FINAL_DROP = ['Year']

# %%
## set save location 

os.makedirs(OUTPUT_FOLDER, exist_ok=True)
print(f"[i] Saving .csv's to {OUTPUT_FOLDER}")
## loop through years
for year in year_bins:
    
    ## save temp slices of dfs to save.
    temp_df = chicago_final.loc[year]
    temp_df = temp_df.sort_index()
    temp_df = temp_df.reset_index(drop=True)
    temp_df = temp_df.drop(columns=FINAL_DROP)

    # save as csv to output folder
    fname_temp = f"{OUTPUT_FOLDER}Chicago-Crime_{year}.csv"#.gz
    temp_df.to_csv(fname_temp,index=False)

    print(f"- Succesfully saved {fname_temp}")
# Out:
# [i] Saving .csv's to Data/Chicago/
# - Succesfully saved Data/Chicago/Chicago-Crime_2001.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2002.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2003.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2004.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2005.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2006.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2007.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2008.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2009.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2010.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2011.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2012.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2013.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2014.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2015.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2016.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2017.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2018.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2019.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2020.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2021.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2022.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2023.csv

# %%
saved_files = sorted(glob.glob(OUTPUT_FOLDER+'*.*csv'))
saved_files
# Out:
# ['Data/Chicago\\Chicago-Crime_2001.csv',
#  'Data/Chicago\\Chicago-Crime_2002.csv',
#  'Data/Chicago\\Chicago-Crime_2003.csv',
#  'Data/Chicago\\Chicago-Crime_2004.csv',
#  'Data/Chicago\\Chicago-Crime_2005.csv',
#  'Data/Chicago\\Chicago-Crime_2006.csv',
#  'Data/Chicago\\Chicago-Crime_2007.csv',
#  'Data/Chicago\\Chicago-Crime_2008.csv',
#  'Data/Chicago\\Chicago-Crime_2009.csv',
#  'Data/Chicago\\Chicago-Crime_2010.csv',
#  'Data/Chicago\\Chicago-Crime_2011.csv',
#  'Data/Chicago\\Chicago-Crime_2012.csv',
#  'Data/Chicago\\Chicago-Crime_2013.csv',
#  'Data/Chicago\\Chicago-Crime_2014.csv',
#  'Data/Chicago\\Chicago-Crime_2015.csv',
#  'Data/Chicago\\Chicago-Crime_2016.csv',
#  'Data/Chicago\\Chicago-Crime_2017.csv',
#  'Data/Chicago\\Chicago-Crime_2018.csv',
#  'Data/Chicago\\Chicago-Crime_2019.csv',
#  'Data/Chicago\\Chicago-Crime_2020.csv',
#  'Data/Chicago\\Chicago-Crime_2021.csv',
#  'Data/Chicago\\Chicago-Crime_2022.csv',
#  'Data/Chicago\\Chicago-Crime_2023.csv']

# %%
## create a README.txt for the zip files
readme = """Source URL: 
- https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
- Filtered for years 2000-Present.

Downloaded 07/18/2022
- Files are split into 1 year per file.

EXAMPLE USAGE:
>> import glob
>> import pandas as pd
>> folder = "Data/Chicago/"
>> crime_files = sorted(glob.glob(folder+"*.csv"))
>> df = pd.concat([pd.read_csv(f) for f in crime_files])
"""
print(readme)


with open(f"{OUTPUT_FOLDER}README.txt",'w') as f:
    f.write(readme)
# Out:
# Source URL:
# - https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
# - Filtered for years 2000-Present.
#
# Downloaded 07/18/2022
# - Files are split into 1 year per file.
#
# EXAMPLE USAGE:
# >> import glob
# >> import pandas as pd
# >> folder = "Data/Chicago/"
# >> crime_files = sorted(glob.glob(folder+"*.csv"))
# >> df = pd.concat([pd.read_csv(f) for f in crime_files])

# %%
# get list of files from folder
crime_files = sorted(glob.glob(OUTPUT_FOLDER+"*.csv"))
df = pd.concat([pd.read_csv(f, nrows=5) for f in crime_files])
df
# Out:
#           ID                    Date        Primary Type  \
# 0    3769790  01/01/2001 01:00:00 PM               THEFT
# 1    1311123  01/01/2001 01:00:00 AM     CRIMINAL DAMAGE
# 2    1325760  01/01/2001 01:00:00 PM           NARCOTICS
# 3    6808288  01/01/2001 01:00:00 PM               THEFT
# 4    1319931  01/01/2001 01:00:00 PM             BATTERY
# ..       ...                     ...                 ...
# 0   12942951  01/01/2023 01:00:00 AM  DECEPTIVE PRACTICE
# 1   12938864  01/01/2023 01:00:00 AM     CRIMINAL DAMAGE
# 2   12938591  01/01/2023 01:00:00 AM     CRIMINAL DAMAGE
# 3   12950130  01/01/2023 01:00:00 AM     CRIMINAL DAMAGE
# 4   12939232  01/01/2023 01:00:00 AM     CRIMINAL DAMAGE
#
#                       Description          Location Description  Arrest  \
# 0         AGG: FINANCIAL ID THEFT                     RESIDENCE   False
# 1                      TO VEHICLE                        STREET   False
# 2    POSS: CANNABIS 30GMS OR LESS  GOVERNMENT BUILDING/PROPERTY    True
# 3   FINANCIAL ID THEFT: OVER $300                     APARTMENT   False
# 4                          SIMPLE                     RESIDENCE   False
# ..                            ...                           ...     ...
# 0           ILLEGAL USE CASH CARD                     APARTMENT   False
# 1                      TO VEHICLE                        STREET   False
# 2                     TO PROPERTY            RESIDENCE - GARAGE   False
# 3                     TO PROPERTY                     RESIDENCE   False
# 4                     TO PROPERTY                     RESIDENCE   False
#
#     Domestic  Beat  District  Ward   Latitude  Longitude
# 0      False   523       5.0  34.0  41.673171 -87.638000
# 1      False  1223      12.0   NaN  41.854014 -87.681909
# 2      False  1033      10.0   NaN        NaN        NaN
# 3      False   213       2.0   3.0  41.822551 -87.615632
# 4       True   825       8.0   NaN  41.783892 -87.684841
# ..       ...   ...       ...   ...        ...        ...
# 0      False   723       7.0  20.0  41.775359 -87.645890
# 1      False  2524      25.0  31.0  41.926884 -87.720720
# 2      False  1713      17.0  33.0  41.971086 -87.712217
# 3      False   732       7.0   6.0  41.766343 -87.638381
# 4      False   421       4.0   7.0  41.758091 -87.554612
#
# [115 rows x 12 columns]

# %%
years = df['Date'].map(lambda x: x.split()[0].split('/')[-1])
years.value_counts().sort_index()
# Out:
# 2001    5
# 2002    5
# 2003    5
# 2004    5
# 2005    5
# 2006    5
# 2007    5
# 2008    5
# 2009    5
# 2010    5
# 2011    5
# 2012    5
# 2013    5
# 2014    5
# 2015    5
# 2016    5
# 2017    5
# 2018    5
# 2019    5
# 2020    5
# 2021    5
# 2022    5
# 2023    5
# Name: Date, dtype: int64

# %%
# !pip install holidays
# Out:
# Requirement already satisfied: holidays in c:\users\awot1\anaconda3\envs\dojo-env\lib\site-packages (0.32)
# Requirement already satisfied: python-dateutil in c:\users\awot1\anaconda3\envs\dojo-env\lib\site-packages (from holidays) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\awot1\anaconda3\envs\dojo-env\lib\site-packages (from python-dateutil->holidays) (1.16.0)
# WARNING: Error parsing requirements for numpy: [Errno 2] No such file or directory: 'c:\\users\\awot1\\anaconda3\\envs\\dojo-env\\lib\\site-packages\\numpy-1.24.3.dist-info\\METADATA'

# %%
import holidays
import datetime as dt
from holidays import country_holidays

# %%
## making a date range that covers full dataset
all_days = pd.date_range(df["Date"].min(), df["Date"].max())
all_days
# Out:
# DatetimeIndex(['2001-01-01 01:00:00', '2001-01-02 01:00:00',
#                '2001-01-03 01:00:00', '2001-01-04 01:00:00',
#                '2001-01-05 01:00:00', '2001-01-06 01:00:00',
#                '2001-01-07 01:00:00', '2001-01-08 01:00:00',
#                '2001-01-09 01:00:00', '2001-01-10 01:00:00',
#                ...
#                '2022-12-23 01:00:00', '2022-12-24 01:00:00',
#                '2022-12-25 01:00:00', '2022-12-26 01:00:00',
#                '2022-12-27 01:00:00', '2022-12-28 01:00:00',
#                '2022-12-29 01:00:00', '2022-12-30 01:00:00',
#                '2022-12-31 01:00:00', '2023-01-01 01:00:00'],
#               dtype='datetime64[ns]', length=8036, freq='D')

# %%
df1=df.copy()

# %%
df1.head()
# Out:
#         ID                    Date     Primary Type  \
# 0  3769790  01/01/2001 01:00:00 PM            THEFT
# 1  1311123  01/01/2001 01:00:00 AM  CRIMINAL DAMAGE
# 2  1325760  01/01/2001 01:00:00 PM        NARCOTICS
# 3  6808288  01/01/2001 01:00:00 PM            THEFT
# 4  1319931  01/01/2001 01:00:00 PM          BATTERY
#
#                      Description          Location Description  Arrest  \
# 0        AGG: FINANCIAL ID THEFT                     RESIDENCE   False
# 1                     TO VEHICLE                        STREET   False
# 2   POSS: CANNABIS 30GMS OR LESS  GOVERNMENT BUILDING/PROPERTY    True
# 3  FINANCIAL ID THEFT: OVER $300                     APARTMENT   False
# 4                         SIMPLE                     RESIDENCE   False
#
#    Domestic  Beat  District  Ward   Latitude  Longitude
# 0     False   523       5.0  34.0  41.673171 -87.638000
# 1     False  1223      12.0   NaN  41.854014 -87.681909
# 2     False  1033      10.0   NaN        NaN        NaN
# 3     False   213       2.0   3.0  41.822551 -87.615632
# 4      True   825       8.0   NaN  41.783892 -87.684841

# %%
df['Date'].unique()
# Out:
# array([datetime.date(2011, 1, 1), datetime.date(2012, 1, 1),
#        datetime.date(2013, 1, 1), datetime.date(2014, 1, 1),
#        datetime.date(2015, 1, 1), datetime.date(2016, 1, 1),
#        datetime.date(2017, 1, 1), datetime.date(2018, 1, 1),
#        datetime.date(2019, 1, 1), datetime.date(2020, 1, 1),
#        datetime.date(2021, 1, 1), datetime.date(2022, 1, 1)], dtype=object)

# %%
import datetime as dt

# %%
#Add a datetime column based on the string in the "date" column
df1['datetime'] = pd.to_datetime(df1['Date'])
df1.info()
df1.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115 entries, 0 to 4
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    115 non-null    int64
#  1   Date                  115 non-null    object
#  2   Primary Type          115 non-null    object
#  3   Description           115 non-null    object
#  4   Location Description  115 non-null    object
#  5   Arrest                115 non-null    bool
#  6   Domestic              115 non-null    bool
#  7   Beat                  115 non-null    int64
#  8   District              115 non-null    float64
#  9   Ward                  110 non-null    float64
#  10  Latitude              106 non-null    float64
#  11  Longitude             106 non-null    float64
#  12  datetime              115 non-null    datetime64[ns]
# dtypes: bool(2), datetime64[ns](1), float64(4), int64(2), object(4)
# memory usage: 11.0+ KB
#         ID                    Date     Primary Type  \
# 0  3769790  01/01/2001 01:00:00 PM            THEFT
# 1  1311123  01/01/2001 01:00:00 AM  CRIMINAL DAMAGE
# 2  1325760  01/01/2001 01:00:00 PM        NARCOTICS
#
#                     Description          Location Description  Arrest  \
# 0       AGG: FINANCIAL ID THEFT                     RESIDENCE   False
# 1                    TO VEHICLE                        STREET   False
# 2  POSS: CANNABIS 30GMS OR LESS  GOVERNMENT BUILDING/PROPERTY    True
#
#    Domestic  Beat  District  Ward   Latitude  Longitude            datetime
# 0     False   523       5.0  34.0  41.673171 -87.638000 2001-01-01 13:00:00
# 1     False  1223      12.0   NaN  41.854014 -87.681909 2001-01-01 01:00:00
# 2     False  1033      10.0   NaN        NaN        NaN 2001-01-01 13:00:00

# %%
df1 = df1.set_index('datetime')
df1
# Out:
#                            ID                    Date        Primary Type  \
# datetime
# 2001-01-01 13:00:00   3769790  01/01/2001 01:00:00 PM               THEFT
# 2001-01-01 01:00:00   1311123  01/01/2001 01:00:00 AM     CRIMINAL DAMAGE
# 2001-01-01 13:00:00   1325760  01/01/2001 01:00:00 PM           NARCOTICS
# 2001-01-01 13:00:00   6808288  01/01/2001 01:00:00 PM               THEFT
# 2001-01-01 13:00:00   1319931  01/01/2001 01:00:00 PM             BATTERY
# ...                       ...                     ...                 ...
# 2023-01-01 01:00:00  12942951  01/01/2023 01:00:00 AM  DECEPTIVE PRACTICE
# 2023-01-01 01:00:00  12938864  01/01/2023 01:00:00 AM     CRIMINAL DAMAGE
# 2023-01-01 01:00:00  12938591  01/01/2023 01:00:00 AM     CRIMINAL DAMAGE
# 2023-01-01 01:00:00  12950130  01/01/2023 01:00:00 AM     CRIMINAL DAMAGE
# 2023-01-01 01:00:00  12939232  01/01/2023 01:00:00 AM     CRIMINAL DAMAGE
#
#                                        Description  \
# datetime
# 2001-01-01 13:00:00        AGG: FINANCIAL ID THEFT
# 2001-01-01 01:00:00                     TO VEHICLE
# 2001-01-01 13:00:00   POSS: CANNABIS 30GMS OR LESS
# 2001-01-01 13:00:00  FINANCIAL ID THEFT: OVER $300
# 2001-01-01 13:00:00                         SIMPLE
# ...                                            ...
# 2023-01-01 01:00:00          ILLEGAL USE CASH CARD
# 2023-01-01 01:00:00                     TO VEHICLE
# 2023-01-01 01:00:00                    TO PROPERTY
# 2023-01-01 01:00:00                    TO PROPERTY
# 2023-01-01 01:00:00                    TO PROPERTY
#
#                              Location Description  Arrest  Domestic  Beat  \
# datetime
# 2001-01-01 13:00:00                     RESIDENCE   False     False   523
# 2001-01-01 01:00:00                        STREET   False     False  1223
# 2001-01-01 13:00:00  GOVERNMENT BUILDING/PROPERTY    True     False  1033
# 2001-01-01 13:00:00                     APARTMENT   False     False   213
# 2001-01-01 13:00:00                     RESIDENCE   False      True   825
# ...                                           ...     ...       ...   ...
# 2023-01-01 01:00:00                     APARTMENT   False     False   723
# 2023-01-01 01:00:00                        STREET   False     False  2524
# 2023-01-01 01:00:00            RESIDENCE - GARAGE   False     False  1713
# 2023-01-01 01:00:00                     RESIDENCE   False     False   732
# 2023-01-01 01:00:00                     RESIDENCE   False     False   421
#
#                      District  Ward   Latitude  Longitude
# datetime
# 2001-01-01 13:00:00       5.0  34.0  41.673171 -87.638000
# 2001-01-01 01:00:00      12.0   NaN  41.854014 -87.681909
# 2001-01-01 13:00:00      10.0   NaN        NaN        NaN
# 2001-01-01 13:00:00       2.0   3.0  41.822551 -87.615632
# 2001-01-01 13:00:00       8.0   NaN  41.783892 -87.684841
# ...                       ...   ...        ...        ...
# 2023-01-01 01:00:00       7.0  20.0  41.775359 -87.645890
# 2023-01-01 01:00:00      25.0  31.0  41.926884 -87.720720
# 2023-01-01 01:00:00      17.0  33.0  41.971086 -87.712217
# 2023-01-01 01:00:00       7.0   6.0  41.766343 -87.638381
# 2023-01-01 01:00:00       4.0   7.0  41.758091 -87.554612
#
# [115 rows x 12 columns]

# %%
# Which district has the most crimes? Which has the least?

# %%
## Inspect the value_counts for the different types of crimes
crime_counts = df1['Primary Type'].value_counts()
crime_counts
# Out:
# THEFT                         19
# CRIMINAL DAMAGE               10
# BATTERY                        9
# DECEPTIVE PRACTICE             5
# MOTOR VEHICLE THEFT            4
# OTHER OFFENSE                  3
# ASSAULT                        3
# SEX OFFENSE                    2
# BURGLARY                       2
# OFFENSE INVOLVING CHILDREN     1
# CRIM SEXUAL ASSAULT            1
# PUBLIC PEACE VIOLATION         1
# Name: Primary Type, dtype: int64

# %%
df2=df1.groupby('District')['Primary Type'].count()
df2
# Out:
# District
# 1.0     3
# 2.0     2
# 3.0     3
# 4.0     2
# 5.0     2
# 6.0     2
# 7.0     4
# 8.0     3
# 10.0    4
# 11.0    3
# 12.0    5
# 14.0    2
# 15.0    1
# 16.0    1
# 18.0    6
# 19.0    5
# 20.0    1
# 22.0    2
# 24.0    5
# 25.0    4
# Name: Primary Type, dtype: int64

# %%
crimedf=pd.DataFrame(data=df2)

# %%
crimedf
# Out:
#           Primary Type
# District
# 1.0                  3
# 2.0                  2
# 3.0                  3
# 4.0                  2
# 5.0                  2
# 6.0                  2
# 7.0                  4
# 8.0                  3
# 10.0                 4
# 11.0                 3
# 12.0                 5
# 14.0                 2
# 15.0                 1
# 16.0                 1
# 18.0                 6
# 19.0                 5
# 20.0                 1
# 22.0                 2
# 24.0                 5
# 25.0                 4

# %%
crimedf.plot()
# Out:
# <Axes: xlabel='District'>

# %%
crimedf.max()
# Out:
# Primary Type    6
# dtype: int64

# %%
crimedf.loc[crimedf['Primary Type']==6]
# Out:
#           Primary Type
# District
# 18.0                 6

# %%
crimedf.min()
# Out:
# Primary Type    1
# dtype: int64

# %%
crimedf.loc[crimedf['Primary Type']==1]
# Out:
#           Primary Type
# District
# 15.0                 1
# 16.0                 1
# 20.0                 1

# %% [markdown]
# district 18 has maximum crime as seen in the graph while district 15,16 and 20 has the lowest crimes.

# %% [markdown]
# # Topic 2) Crimes Across the Years:Is the total number of crimes increasing or decreasing across the years?Are there any individual crimes that are doing the opposite (e.g decreasing when overall crime is increasing or vice-versa)?

# %%
## Engineering Features using components of the date/time
df1['Year']  = df1.index.year
df1
# 2021-01-01 13:00:00       6.0   8.0  41.757849 -87.601708  2021           NaN
# 2021-01-01 01:00:00      25.0  37.0  41.903649 -87.745987  2021           NaN
# 2021-01-01 01:00:00      18.0  42.0  41.893652 -87.622726  2021           NaN
# 2021-01-01 01:00:00      10.0  24.0  41.855968 -87.718813  2021           NaN
# 2022-01-01 13:00:00      25.0  29.0  41.911505 -87.802196  2022           NaN
# 2022-01-01 01:00:00      10.0  22.0  41.845600 -87.717264  2022           NaN
# 2022-01-01 01:00:00      11.0  28.0  41.879687 -87.731805  2022           NaN
# 2022-01-01 13:00:00       1.0   4.0  41.839811 -87.617142  2022           NaN
# 2022-01-01 01:00:00      24.0  50.0  41.996603 -87.695945  2022           NaN
#
#                      crime
# datetime
# 2011-01-01 01:00:00    NaN
# 2011-01-01 13:00:00    NaN
# 2011-01-01 01:00:00    NaN
# 2011-01-01 01:00:00    NaN
# 2011-01-01 01:00:00    NaN
# 2012-01-01 01:00:00    NaN
# 2012-01-01 13:00:00    NaN
# 2012-01-01 13:00:00    NaN
# 2012-01-01 13:00:00    NaN
# 2012-01-01 01:00:00    NaN
# 2013-01-01 01:00:00    NaN
# 2013-01-01 01:00:00    NaN
# 2013-01-01 01:00:00    NaN
# 2013-01-01 13:00:00    NaN
# 2013-01-01 13:00:00    NaN
# 2014-01-01 01:00:00    NaN
# 2014-01-01 01:00:00    NaN
# 2014-01-01 13:00:00    NaN
# 2014-01-01 13:00:00    NaN
# 2014-01-01 13:00:00    NaN
# 2015-01-01 13:00:00    NaN
# 2015-01-01 01:00:00    NaN
# 2015-01-01 01:00:00    NaN
# 2015-01-01 13:00:00    NaN
# 2015-01-01 01:00:00    NaN
# 2016-01-01 01:00:00    NaN
# 2016-01-01 01:00:00    NaN
# 2016-01-01 01:00:00    NaN
# 2016-01-01 13:00:00    NaN
# 2016-01-01 01:00:00    NaN
# 2017-01-01 01:00:00    NaN
# 2017-01-01 01:00:00    NaN
# 2017-01-01 01:00:00    NaN
# 2017-01-01 01:00:00    NaN
# 2017-01-01 13:00:00    NaN
# 2018-01-01 01:00:00    NaN
# 2018-01-01 13:00:00    NaN
# 2018-01-01 01:00:00    NaN
# 2018-01-01 13:00:00    NaN
# 2018-01-01 13:00:00    NaN
# 2019-01-01 01:00:00    NaN
# 2019-01-01 13:00:00    NaN
# 2019-01-01 01:00:00    NaN
# 2019-01-01 13:00:00    NaN
# 2019-01-01 01:00:00    NaN
# 2020-01-01 13:00:00    NaN
# 2020-01-01 01:00:00    NaN
# 2020-01-01 13:00:00    NaN
# 2020-01-01 01:00:00    NaN
# 2020-01-01 01:00:00    NaN
# 2021-01-01 13:00:00    NaN
# 2021-01-01 13:00:00    NaN
# 2021-01-01 01:00:00    NaN
# 2021-01-01 01:00:00    NaN
# 2021-01-01 01:00:00    NaN
# 2022-01-01 13:00:00    NaN
# 2022-01-01 01:00:00    NaN
# 2022-01-01 01:00:00    NaN
# 2022-01-01 13:00:00    NaN
# 2022-01-01 01:00:00    NaN

# %%
#df3=df1.groupby('Primary Type')['Year'].count()
#df3
## Get # of crimes by Hour
crimes_by_year = df1.groupby('Primary Type')['Year'].value_counts().sort_index()
crimes_by_year
# Out:
# Primary Type                Year
# ASSAULT                     2015    1
#                             2020    1
#                             2021    1
# BATTERY                     2013    1
#                             2014    1
#                             2015    1
#                             2016    1
#                             2017    1
#                             2018    1
#                             2020    1
#                             2021    2
# BURGLARY                    2018    1
#                             2020    1
# CRIM SEXUAL ASSAULT         2017    1
# CRIMINAL DAMAGE             2011    1
#                             2012    1
#                             2013    1
#                             2016    1
#                             2017    2
#                             2019    1
#                             2021    1
#                             2022    2
# DECEPTIVE PRACTICE          2015    1
#                             2019    2
#                             2020    1
#                             2022    1
# MOTOR VEHICLE THEFT         2014    1
#                             2015    1
#                             2018    1
#                             2020    1
# OFFENSE INVOLVING CHILDREN  2012    1
# OTHER OFFENSE               2014    1
#                             2018    1
#                             2022    1
# PUBLIC PEACE VIOLATION      2021    1
# SEX OFFENSE                 2012    1
#                             2016    1
# THEFT                       2011    4
#                             2012    2
#                             2013    3
#                             2014    2
#                             2015    1
#                             2016    2
#                             2017    1
#                             2018    1
#                             2019    2
#                             2022    1
# Name: Year, dtype: int64

# %%
## convert to dataframe and reset_index()
plot_df = crimes_by_year.to_frame('# of Crimes').reset_index()
plot_df.head()
# Out:
#   Primary Type  Year  # of Crimes
# 0      ASSAULT  2015            1
# 1      ASSAULT  2020            1
# 2      ASSAULT  2021            1
# 3      BATTERY  2013            1
# 4      BATTERY  2014            1

# %%
## save year counts
year_counts = plot_df['Year'].value_counts().sort_index()
year_counts.plot(style='o-',grid=True,ylabel='# of Crimes', xlabel='Year');

# %%
## visualizing again with years removed
sns.countplot(data=plot_df, x='Year',palette='dark');

# %% [markdown]
# overall the crime has increased but on some years the crime has decreased from where it was, during 2012 to 2013 it has decreased a bit then it picked up after 2013. so on average, the crime has increased over the years eventhough it has stayed the same and decreased a bit on some year intervals but on average it has increased over the years.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(data=plot_df, x='Year',y='# of Crimes',markers=True,
                  hue='Primary Type',ax=ax,)
ax.legend(bbox_to_anchor=[1,1]);

# %%
g = sns.catplot(data=plot_df, x='Year', y='# of Crimes',
                kind='point',aspect=2, height=4,
                hue='Primary Type', col='Primary Type',col_wrap=2,
               sharey=False, sharex=False)
[ax.grid(axis='x') for ax in g.axes];

# %% [markdown]
# bulglary has no increase or decrease during the years,sexual assault increased from 2020 to 2021,criminal damage has not increased or decreased,theft however, has decreased over the years while others on average increased.

# %% [markdown]
# # Topic 4) Comparing Months:What months have the most crime? What months have the least?Are there any individual crimes that do not follow this pattern? If so, which crimes?

# %%
# we need to resample it monthly

# %%
df1.drop(columns=['crime_counts','crime'],inplace=True)

# %%
df1.head(2)
# Out:
#                           ID        Date Primary Type    Description  \
# datetime
# 2011-01-01 01:00:00  7869887  2011-01-01        THEFT  FROM BUILDING
# 2011-01-01 13:00:00  7872358  2011-01-01        THEFT  FROM BUILDING
#
#                     Location Description  Arrest  Domestic  Beat  District  \
# datetime
# 2011-01-01 01:00:00          HOTEL/MOTEL   False     False  2432      24.0
# 2011-01-01 13:00:00            RESIDENCE   False     False  2123       2.0
#
#                      Ward   Latitude  Longitude  Year  Month MonthName
# datetime
# 2011-01-01 01:00:00  40.0  42.000432 -87.661390  2011      1   January
# 2011-01-01 13:00:00   4.0  41.816112 -87.600619  2011      1   January

# %%
df1=df.copy()
ts_H = df1.resample("b").mean()
ts_H.name = 'Resampled'
ts_H.head()
# Out:
# C:\Users\awot1\AppData\Local\Temp\ipykernel_20196\3449678877.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ts_H = df1.resample("b").mean()
#                    ID  Arrest  Domestic    Beat  District  Ward   Latitude  \
# datetime
# 2010-12-31  7872940.0     0.0       0.2  1807.2      13.2  21.6  41.888195
# 2011-01-03        NaN     NaN       NaN     NaN       NaN   NaN        NaN
# 2011-01-04        NaN     NaN       NaN     NaN       NaN   NaN        NaN
# 2011-01-05        NaN     NaN       NaN     NaN       NaN   NaN        NaN
# 2011-01-06        NaN     NaN       NaN     NaN       NaN   NaN        NaN
#
#             Longitude    Year  crime_counts
# datetime
# 2010-12-31 -87.647489  2011.0           NaN
# 2011-01-03        NaN     NaN           NaN
# 2011-01-04        NaN     NaN           NaN
# 2011-01-05        NaN     NaN           NaN
# 2011-01-06        NaN     NaN           NaN

# %%
 ts_H .index
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-03', '2011-01-04', '2011-01-05',
#                '2011-01-06', '2011-01-07', '2011-01-10', '2011-01-11',
#                '2011-01-12', '2011-01-13',
#                ...
#                '2021-12-20', '2021-12-21', '2021-12-22', '2021-12-23',
#                '2021-12-24', '2021-12-27', '2021-12-28', '2021-12-29',
#                '2021-12-30', '2021-12-31'],
#               dtype='datetime64[ns]', name='datetime', length=2871, freq='B')

# %%
ts_H['Month']= ts_H.index.month
ts_H['Month'].head()
# Out:
# datetime
# 2010-12-31    12
# 2011-01-03     1
# 2011-01-04     1
# 2011-01-05     1
# 2011-01-06     1
# Freq: B, Name: Month, dtype: int64

# %%
## Extracting the Month
ts_H['Month'] = ts_H.index.month
ts_H['MonthName'] =ts_H.index.month_name()
ts_H.head(3)
# Out:
#                    ID  Arrest  Domestic    Beat  District  Ward   Latitude  \
# datetime
# 2010-12-31  7872940.0     0.0       0.2  1807.2      13.2  21.6  41.888195
# 2011-01-03        NaN     NaN       NaN     NaN       NaN   NaN        NaN
# 2011-01-04        NaN     NaN       NaN     NaN       NaN   NaN        NaN
#
#             Longitude    Year  crime_counts  Month MonthName
# datetime
# 2010-12-31 -87.647489  2011.0           NaN     12  December
# 2011-01-03        NaN     NaN           NaN      1   January
# 2011-01-04        NaN     NaN           NaN      1   January

# %%
# saving lookup for number vs name
unique_months = ts_H.drop_duplicates(subset=['Month']).sort_values('Month')
month_lookup =dict(zip(unique_months['Month'],unique_months['MonthName']))
month_lookup
# Out:
# {1: 'January',
#  2: 'February',
#  3: 'March',
#  4: 'April',
#  5: 'May',
#  6: 'June',
#  7: 'July',
#  8: 'August',
#  9: 'September',
#  10: 'October',
#  11: 'November',
#  12: 'December'}

# %%
ax = sns.countplot(data=ts_H, x='MonthName',palette='dark',order=month_lookup.values());
# Rotate xtick labels and align the text to the bar
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right');

# %%
## save month counts
month_counts = ts_H['MonthName'].value_counts()[month_lookup.values()]
# year_counts = df.groupby("Year").size()
ax = month_counts.plot(style='o-',grid=True,
                       ylabel='# of Crimes',
                       xlabel='Month');

# %% [markdown]
# during the month of january to february has the lowest cime with february being the lowest, looks like there is more crime at warmer temperatures than the colder months
# it seems that january, may, july, august,october,december have the highest crimes.
